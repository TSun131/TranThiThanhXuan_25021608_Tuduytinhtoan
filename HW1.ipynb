# %%
#Bài 1
n=int(input())
print(2*n)
# Out:
# 10

# %%
#Bài 2
a,b=map(int,input().split())
s=(a/2)*(a/2)*3.14
print(round((a+b)*2-s,2))
# Out:
# 5.21

# %%
#Bài 3
c=input()
u=c.upper()
l=c.lower()
if c!=u:
    print(u)
else:
    print(l)
# Out:
# b

# %%
#Bài 4
c=input()
d=ord(c)
if 65<=d<=90 or 97<=d<=122:
    print(c,"là kí tự alphabet")
else:
    print(c,"không phải la kí tự alphabet")
# Out:
# a là kí tự alphabet

# %%
#Bài 5
c=input()
d=ord(c)-1
if d<65: 
    d=65
print(chr(d))
# Out:
# A

# %%
#Bài 6
a,b,c=map(float,input().split())
p=float((a+b+c)/2)
s=float((p*(p-a)*(p-b)*(p-c))**0.5)
if s!=0:
    print(round(s,1))
else:
    print("không phải 3 cạnh của tam giác")
# Out:
# không phải 3 cạnh của tam giác

# %%
#Bài 7
s=input()
print(s[4],s[8])
# Out:
# h o

# %%
#Bài 8
n=input("Ten chu ho: ") 
t=input("Chi so thang truoc: ")
n=input("Chi so thang nay: ")

# %%
#Bài 9
n=int(input())
if n%2==0:
    print(n,"là số chẵn")
else:
    print(n,"là số lẻ")
# Out:
# 5 là số lẻ

# %%
#Bài 10
n=int(input())
if n%10==5:
    print("True")
else:
    print("False")
# Out:
# False

# %%
#Bài 11
n=int(input())
if n%3==0 and n%5==0:
    print("True")
else:
    print("False")
# Out:
# False

# %%
#Bài 12
n=int(input())
if 2025-n>=18:
    print("Đủ tuổi")
else:
    print("Chưa đủ tuổi")
# Out:
# Đủ tuổi

# %%
#Bài 13
a,b=map(int,input().split())
if a==b:
    print("Bằng nhau")
elif a>b:
    print(a)    
else:
    print(b)
# Out:
# 2

# %%
#Bài 14
c = input("Nhap 1 ky tu: ")
if c.isalpha():
    print("Chu cai")
elif c.isdigit():
    print("Chu so")
else:
    print("Khong phai chu cai hay chu so")
# Out:
# Chu so

# %%
#Bài 15
n=int(input())
if n>=8:
    print("Giỏi")
elif n>=6.5:
    print("Khá")
elif n>=5:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Giỏi

# %%
#Bài 16
n=int(input())
if n%400==0 or (n%4==0 and n%100!=0):
    print("Năm nhuận")
else:
    print("Không phải năm nhuận")
# Out:
# Không phải năm nhuận

# %%
#Bài 17
n=int(input())
match n:
    case 0:
        print("Không")
    case 1:
        print("Một")                
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bốn")
    case 5:
        print("Năm")
    case 6:
        print("Sáu")            
    case 7:
        print("Bảy")
    case 8:
        print("Tám")
    case 9:
        print("Chín")
# Out:
# Bốn

# %%
#Bài 18
n=int(input())
if n<4:
    print("Học lại")
else:
    print("Qua môn")
# Out:
# Qua môn

# %%
#Bài 19
n=int(input())
print(2025-n)
# Out:
# 18

# %%
hs=[
    {"id":1,"n":"TX","s":9},
    {"id":2,"n":"AT","s":8}
]
hs.append({"id":3,"n":"ND","s":7})
for i in hs:
    if i["id"]==2:
        print(i["n"],i["s"])
        break
else:
    print("Không tìm thấy")
for i in hs:
    print(i["s"])
# Out:
# AT 8
# 9
# 8
# 7
